# %%
# import header files
# %matplotlib inline
import torch
import torch.nn as nn
import torchvision
from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import glob
import os
import random
import tensorflow as tf
from tensorflow import keras
import numpy as np
import seaborn as sn
import pandas as pd
from matplotlib import pyplot as plt
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
import time
import copy
import tqdm
import torch
import random
from PIL import Image
import torch.optim as optim
from torchvision import models
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset,DataLoader
from torch import nn
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import transforms
from sklearn.model_selection import KFold

# %%
# load my google drive
import os
def auth_gdrive():
  from google.colab import drive
  if os.path.exists('content/gdrive/My Drive'): return
  drive.mount('/content/gdrive')
def load_gdrive_dataset():
  loader_assets = 'CVPollen23E.zip'
  auth_gdrive()

# %%
# mount my google drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
load_gdrive_dataset()
# Out:
# Mounted at /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# unzip  dataset
# !unzip "/content/gdrive/MyDrive/CVPollen23E.zip"
# Out:
# Archive:  /content/gdrive/MyDrive/CVPollen23E.zip
#    creating: CVPollen23E/
#    creating: CVPollen23E/test/
#    creating: CVPollen23E/test/1.Anadenanthera/
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_15.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_16.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_17.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_18.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_19.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_20.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_21.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_22.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_23.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_24.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_25.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_26.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_27.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_28.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_29.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_30.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_31.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_32.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_33.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_34.jpg
#   inflating: CVPollen23E/test/1.Anadenanthera/anadenanthera_35.jpg
#    creating: CVPollen23E/test/10.Faramea/
#   inflating: CVPollen23E/test/10.Faramea/faramea_01.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_02.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_03.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_04.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_05.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_06.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_07.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_08.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_09.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_10.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_11.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_12.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_13.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_14.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_15.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_16.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_17.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_18.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_19.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_20.jpg
#   inflating: CVPollen23E/test/10.Faramea/faramea_21.jpg
#    creating: CVPollen23E/test/11.Hyptis/
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_01.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_02.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_03.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_04.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_05.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_06.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_07.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_08.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_09.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_10.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_11.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_12.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_13.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_14.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_15.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_16.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_17.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_18.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_19.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_20.jpg
#   inflating: CVPollen23E/test/11.Hyptis/hyptis_21.jpg
#    creating: CVPollen23E/test/12.Mabea/
#   inflating: CVPollen23E/test/12.Mabea/mabea_01.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_02.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_03.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_04.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_05.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_06.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_07.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_08.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_09.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_10.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_11.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_12.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_13.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_14.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_15.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_16.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_17.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_18.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_19.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_21.jpg
#   inflating: CVPollen23E/test/12.Mabea/mabea_22.jpg
#    creating: CVPollen23E/test/13.Matayba/
#   inflating: CVPollen23E/test/13.Matayba/matayba_01.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_02.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_03.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_04.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_05.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_06.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_07.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_08.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_09.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_10.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_11.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_12.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_13.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_14.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_15.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_16.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_17.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_18.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_19.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_20.jpg
#   inflating: CVPollen23E/test/13.Matayba/matayba_21.jpg
#    creating: CVPollen23E/test/14.Mimosa/
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_01.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_02.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_03.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_04.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_05.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_06.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_07.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_08.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_09.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_10.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_11.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_12.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_13.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_14.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_15.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_16.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_17.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_18.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_19.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_20.jpg
#   inflating: CVPollen23E/test/14.Mimosa/mimosa_21.jpg
#    creating: CVPollen23E/test/15.Myrcia/
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_01.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_02.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_03.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_04.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_05.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_06.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_07.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_08.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_09.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_10.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_11.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_12.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_13.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_14.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_15.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_16.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_17.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_18.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_19.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_20.jpg
#   inflating: CVPollen23E/test/15.Myrcia/myrcia_21.jpg
#    creating: CVPollen23E/test/16.Protium/
#   inflating: CVPollen23E/test/16.Protium/protium_01.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_02.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_03.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_04.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_05.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_06.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_07.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_08.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_09.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_10.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_11.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_12.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_13.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_14.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_15.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_16.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_17.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_18.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_19.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_20.jpg
#   inflating: CVPollen23E/test/16.Protium/protium_21.jpg
#    creating: CVPollen23E/test/17.Qualea/
#   inflating: CVPollen23E/test/17.Qualea/qualea_01.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_02.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_03.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_04.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_05.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_06.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_07.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_08.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_09.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_10.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_11.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_12.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_13.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_14.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_15.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_16.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_17.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_18.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_19.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_20.jpg
#   inflating: CVPollen23E/test/17.Qualea/qualea_21.jpg
#    creating: CVPollen23E/test/18.Schinus/
#   inflating: CVPollen23E/test/18.Schinus/schinus_01.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_02.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_03.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_04.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_05.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_06.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_07.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_08.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_09.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_10.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_11.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_12.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_13.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_14.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_15.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_16.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_17.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_18.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_19.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_20.jpg
#   inflating: CVPollen23E/test/18.Schinus/schinus_21.jpg
#    creating: CVPollen23E/test/19.Senegalia/
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (1).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (10).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (11).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (12).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (13).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (14).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (15).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (16).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (17).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (18).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (19).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (2).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (20).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (21).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (3).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (4).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (5).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (6).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (7).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (8).jpg
#   inflating: CVPollen23E/test/19.Senegalia/senegalia (9).jpg
#    creating: CVPollen23E/test/2.Arecaceae/
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_01.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_02.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_03.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_04.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_05.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_06.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_07.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_08.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_09.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_10.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_11.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_12.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_13.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_14.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_15.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_16.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_17.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_18.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_19.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_20.jpg
#   inflating: CVPollen23E/test/2.Arecaceae/arecaceae_21.jpg
#    creating: CVPollen23E/test/20.Serjania/
#   inflating: CVPollen23E/test/20.Serjania/serjania_01.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_02.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_03.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_04.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_05.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_06.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_07.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_08.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_09.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_10.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_11.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_12.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_13.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_14.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_15.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_16.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_17.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_18.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_19.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_20.jpg
#   inflating: CVPollen23E/test/20.Serjania/serjania_21.jpg
#    creating: CVPollen23E/test/21.Syagrus/
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_01.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_02.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_03.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_04.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_05.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_06.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_07.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_08.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_09.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_10.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_11.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_12.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_13.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_14.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_15.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_16.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_17.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_18.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_19.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_20.jpg
#   inflating: CVPollen23E/test/21.Syagrus/syagrus_21.jpg
#    creating: CVPollen23E/test/22.Tridax/
#   inflating: CVPollen23E/test/22.Tridax/tridax_01.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_02.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_03.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_04.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_05.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_06.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_07.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_08.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_09.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_10.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_11.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_12.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_13.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_14.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_15.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_16.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_17.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_18.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_19.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_20.jpg
#   inflating: CVPollen23E/test/22.Tridax/tridax_21.jpg
#    creating: CVPollen23E/test/23.Urochloa/
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (1).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (10).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (11).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (12).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (13).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (14).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (15).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (16).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (17).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (18).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (19).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (2).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (20).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (21).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (3).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (4).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (5).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (6).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (7).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (8).jpg
#   inflating: CVPollen23E/test/23.Urochloa/urochloa (9).jpg
#    creating: CVPollen23E/test/3.Arrabidaea/
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_01.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_02.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_03.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_04.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_05.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_06.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_07.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_08.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_09.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_10.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_11.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_12.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_13.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_14.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_15.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_16.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_17.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_18.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_19.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_20.jpg
#   inflating: CVPollen23E/test/3.Arrabidaea/arrabidaea_21.jpg
#    creating: CVPollen23E/test/4.Cecropia/
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_01.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_02.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_03.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_04.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_05.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_06.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_07.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_08.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_09.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_10.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_11.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_12.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_13.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_14.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_15.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_16.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_17.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_18.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_19.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_20.jpg
#   inflating: CVPollen23E/test/4.Cecropia/cecropia_21.jpg
#    creating: CVPollen23E/test/5.Chromolaena/
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_01.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_02.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_03.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_04.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_05.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_06.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_07.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_08.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_09.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_10.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_11.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_12.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_13.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_14.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_15.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_16.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_17.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_18.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_19.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_20.jpg
#   inflating: CVPollen23E/test/5.Chromolaena/chromolaena_21.jpg
#    creating: CVPollen23E/test/6.Combretum/
#   inflating: CVPollen23E/test/6.Combretum/combretum_01.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_02.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_03.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_04.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_05.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_06.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_07.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_08.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_09.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_10.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_11.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_12.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_13.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_14.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_15.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_16.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_17.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_18.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_19.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_20.jpg
#   inflating: CVPollen23E/test/6.Combretum/combretum_21.jpg
#    creating: CVPollen23E/test/7.Croton/
#   inflating: CVPollen23E/test/7.Croton/croton_01.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_02.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_03.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_04.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_05.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_06.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_07.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_08.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_09.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_10.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_11.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_12.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_13.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_14.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_15.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_16.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_17.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_18.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_20.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_21.jpg
#   inflating: CVPollen23E/test/7.Croton/croton_22.jpg
#    creating: CVPollen23E/test/8.Dipteryx/
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_01.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_02.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_03.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_04.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_05.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_06.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_07.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_08.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_09.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_10.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_11.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_12.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_13.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_14.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_15.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_16.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_17.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_18.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_19.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_20.jpg
#   inflating: CVPollen23E/test/8.Dipteryx/dipteryx_21.jpg
#    creating: CVPollen23E/test/9.Eucalipto/
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_01.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_02.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_03.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_04.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_05.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_06.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_07.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_08.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_09.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_10.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_11.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_12.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_13.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_14.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_15.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_16.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_17.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_18.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_19.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_20.jpg
#   inflating: CVPollen23E/test/9.Eucalipto/eucalipto_21.jpg
#    creating: CVPollen23E/train/
#    creating: CVPollen23E/train/1.Anadenanthera/
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_1367410.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_2350789.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_2440144.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_4403607.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_4409792.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_4486396.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_4542637.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_5140805.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_5393220.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_6500461.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_6613328.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_7921013.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_799794.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_0_965608.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_2_9960744.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_1957824.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_2542906.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_2583629.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_2950192.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_3123730.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_3693514.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_4160879.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_4260449.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_4418158.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_4699967.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_4736277.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_4907653.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_5464617.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_5741720.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_6724594.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_7369973.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_7781235.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_8672792.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_8834130.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_9492486.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_9555301.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_9803292.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_3_9895706.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_1549420.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_2263603.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_252204.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_2695992.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_3589103.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_3869287.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_4153364.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_505561.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_5665700.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_5849926.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_6261692.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_6368936.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_6560382.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_6630991.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_6947232.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_7801424.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_8213128.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_8364506.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_8727083.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_911516.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_9560991.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_9689249.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_4_9907526.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_135488.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_2190748.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_2344060.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_2742762.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_2930381.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_3485514.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_5073274.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_6030124.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_6622401.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_6812674.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_6834919.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_6877935.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_7158876.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_7896318.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_7898686.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_8235387.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_8352871.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_8692667.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_9177671.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_9259257.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_9517067.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_9549519.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_5_9556162.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_1387172.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_2143328.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_2346177.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_2946070.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_3196825.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_3214837.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_3483241.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_4392689.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_4544839.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_461024.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_4698646.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_4712115.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_5149935.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_5181675.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_526794.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_6261190.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_7216343.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_7364702.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_8273267.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_900966.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_9195182.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_9525836.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_6_9728965.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_1097247.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_1717841.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_2305045.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_2833585.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_2897197.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_3574767.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_3784233.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_4578674.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_513544.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_5570159.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_6111397.jpg
#   inflating: CVPollen23E/train/1.Anadenanthera/aug_7_6206593.jpg
#    creating: CVPollen23E/train/10.Faramea/
#   inflating: CVPollen23E/train/10.Faramea/aug_12_1704384.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_1954591.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_1965645.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_2608580.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_2981332.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_3098376.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_3659731.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_3674920.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_485672.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_540626.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_801351.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_8924277.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_12_9887851.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_1365066.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_1528300.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_1960697.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_1963245.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_2608857.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_2809588.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_2851389.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_2880948.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_4510463.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_4617034.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_472048.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_4854522.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_513114.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_5132668.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_5312227.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_5335374.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_6273863.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_7081961.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_7321109.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_8652745.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_8833634.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_9829622.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_13_9946831.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_111345.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_1233168.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_1469050.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_1606017.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_2507323.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_286445.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_2927898.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_3545343.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_3920015.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_4070820.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_4453127.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_4976724.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_5434743.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_5750886.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_5951822.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_6154400.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_6395181.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_6565035.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_673888.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_7423405.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_7764728.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_7794244.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_14_8912451.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_1354122.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_1467166.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_1527925.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_1614187.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_184321.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_2030815.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_2202763.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_2852352.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_4853147.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_4927674.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_5154931.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_5444850.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_5787887.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_598560.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_6252150.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_6369888.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_6406025.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_6764163.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_6926656.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_7394104.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_8095040.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_9478224.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_15_9771870.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_1195502.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_1292515.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_1693668.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_185473.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_2757405.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_2926370.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_344747.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_3452662.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_4029452.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_4158004.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_4777900.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_5191021.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_5388354.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_6595423.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_6815203.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_6942960.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_7178423.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_7634968.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_7988793.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_8653050.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_9017130.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_9218133.jpg
#   inflating: CVPollen23E/train/10.Faramea/aug_16_9532846.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_22.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_23.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_24.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_25.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_26.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_27.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_28.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_29.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_30.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_31.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_32.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_33.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_34.jpg
#   inflating: CVPollen23E/train/10.Faramea/faramea_35.jpg
#    creating: CVPollen23E/train/11.Hyptis/
#   inflating: CVPollen23E/train/11.Hyptis/aug_10_8552280.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_1237492.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_1429927.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_2222110.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_2348785.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_2589420.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_3185535.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_3451860.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_3484776.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_5320806.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_5672088.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_6203089.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_6385569.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_66496.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_7059167.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_7422091.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_7424395.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_8730523.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_9041049.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_11_9653620.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_115077.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_1157999.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_1412260.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_2130251.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_2228017.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_3635238.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_4111554.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_4273812.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_4708127.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_4820952.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_502610.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_5715009.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_6078987.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_6529678.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_7042439.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_7108765.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_7550078.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_8136866.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_8218022.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_8252722.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_8494248.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_9228235.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_12_9334033.jpg
#   inflating: CVPollen23E/train/11.Hyptis/aug_13_1529603.jpg
# ...
#   inflating: CVPollen23E/train/7.Croton/aug_16_978548.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_19.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_23.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_24.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_25.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_26.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_27.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_28.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_29.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_30.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_31.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_32.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_33.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_34.jpg
#   inflating: CVPollen23E/train/7.Croton/croton_35.jpg
#    creating: CVPollen23E/train/8.Dipteryx/
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_2144008.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_2472660.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_4536794.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_4861695.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_5325357.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_5700484.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_6025373.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_6296308.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_6993652.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_7546276.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_7670596.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_8000274.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_12_8051282.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_1451235.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_152594.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_2918805.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_3244712.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_3281415.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_3624246.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_5030046.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_5109669.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_5191173.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_5657215.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_5899990.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_6053079.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_6066584.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_6326927.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_6385874.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_649015.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_676931.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_7351505.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_7634033.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_7656296.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_9168672.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_9520124.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_13_9657727.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_1653322.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_2050411.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_3599071.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_3884481.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_3940136.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_4057763.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_4181771.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_4518997.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_4578481.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_5446954.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_5558929.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_5643568.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_6002946.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_6850310.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_6911614.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_7832808.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_7946564.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_7958490.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_8562556.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_8703790.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_9253504.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_9739664.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_14_997877.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_1739827.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_1756181.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_2071979.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_2210693.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_2221112.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_2277630.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_2783898.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_313228.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_3304689.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_4433983.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_4651250.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_4731499.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_6386728.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_6702941.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_7142447.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_7324682.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_7571511.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_8444792.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_8454665.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_8531158.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_939196.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_9673791.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_15_9881540.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_1440457.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_1659221.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_1739523.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_1772261.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_1806451.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_1968601.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_2328385.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_2745054.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_3577677.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_4722192.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_5512859.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_6330044.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_7317579.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_7366587.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_7526775.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_7576911.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_7879463.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_7994139.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_8159573.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_8257247.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_8751200.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_9162.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/aug_16_9873240.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_22.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_23.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_24.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_25.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_26.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_27.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_28.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_29.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_30.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_31.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_32.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_33.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_34.jpg
#   inflating: CVPollen23E/train/8.Dipteryx/dipteryx_35.jpg
#    creating: CVPollen23E/train/9.Eucalipto/
#   inflating: CVPollen23E/train/9.Eucalipto/aug_11_7683129.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_11_7724660.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_11_8365039.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_11_8408332.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_11_8923083.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_11_8935546.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_1405495.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_1665102.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_2158607.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_2442223.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_249932.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_2748679.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_3404258.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_3455162.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_3476441.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_4070352.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_4321653.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_4484893.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_4985122.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_5244304.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_5354388.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_6267778.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_6455201.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_7080950.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_7880816.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_8564131.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_9121943.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_9267796.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_12_9484472.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_1835405.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_2398317.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_3858509.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_4000139.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_43376.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_440624.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_4836509.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_5102969.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_5391134.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_5449724.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_5927996.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_6342093.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_6444622.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_652827.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_6665030.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_6806113.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_6996987.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_7365414.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_7909570.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_8346977.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_8575173.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_9441481.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_13_9827736.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_1336092.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_2065116.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_2318125.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_2454320.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_2497562.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_307663.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_3780975.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_4463942.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_4700449.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_5128226.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_5464081.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_5557150.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_6085111.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_6262294.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_652823.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_670019.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_6895056.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_6959285.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_7648294.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_8288712.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_8895914.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_9026269.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_14_9378163.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_1122224.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_1154682.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_1910848.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_1941074.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_2238748.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_3662415.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_4629509.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_5398461.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_6229381.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_6276341.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_633225.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_6498920.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_6536196.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_6712595.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_7509387.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_8244019.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_8749658.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_8782474.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_8995450.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_8995950.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_9023131.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_9861878.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_15_9929855.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_1729619.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_2537591.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_3185001.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_3234964.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_3575126.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_3729211.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/aug_16_801573.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_22.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_23.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_24.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_25.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_26.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_27.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_28.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_29.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_30.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_31.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_32.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_33.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_34.jpg
#   inflating: CVPollen23E/train/9.Eucalipto/eucalipto_35.jpg

# %%
# define transforms
train_transforms = torchvision.transforms.Compose([torchvision.transforms.RandomRotation(30),
                                       torchvision.transforms.Resize((84, 84)),
                                       torchvision.transforms.RandomHorizontalFlip(),
                                       torchvision.transforms.ToTensor(),
                                       torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %%
# get data
dataset_train_part = torchvision.datasets.ImageFolder("/content/CVPollen23E/train/", transform=train_transforms)
dataset_test_part = torchvision.datasets.ImageFolder("/content/CVPollen23E/test/", transform=train_transforms)
dataset = ConcatDataset([dataset_train_part, dataset_test_part])

# %%
# define the suggested attention block (VDAB)
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return self.sigmoid(out)
class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=3):
        super(SpatialAttention, self).__init__()
        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 1 if kernel_size == 3 else 3
        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)
class VDAB(nn.Module):
    def __init__(self, in_planes):
        super(VDAB, self).__init__()
        self.ca = ChannelAttention(in_planes)
        self.sa = SpatialAttention()
    def forward(self, x):
        out = x * (self.ca(x))
        out = out * (self.sa(out))
        return out

# %%
# define the proposed method (RCA-Net)
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

        self.vdab = VDAB(planes)

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.vdab(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out

class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

        self.vdab = VDAB(self.expansion*planes)

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = self.vdab(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out

class ResNetVDAB(nn.Module):
    def __init__(self, block, num_blocks, num_classes=23):
        super(ResNetVDAB, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(2048*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18VDAB():
    return ResNetVDAB(BasicBlock, [2,2,2,2])

# %%
# print the model
import math
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResNet18VDAB()
model.to(device)
# Out:
# ResNetVDAB(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (vdab): VDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (linear): Linear(in_features=2048, out_features=23, bias=True)
# )

# %%
# print summary of the model
from torchvision import models
from torchsummary import summary
summary(model, (3, 84, 84))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 84, 84]           1,728
#        BatchNorm2d-2           [-1, 64, 84, 84]             128
#             Conv2d-3           [-1, 64, 84, 84]          36,864
#        BatchNorm2d-4           [-1, 64, 84, 84]             128
#             Conv2d-5           [-1, 64, 84, 84]          36,864
#        BatchNorm2d-6           [-1, 64, 84, 84]             128
#  AdaptiveAvgPool2d-7             [-1, 64, 1, 1]               0
#             Conv2d-8              [-1, 4, 1, 1]             256
#               ReLU-9              [-1, 4, 1, 1]               0
#            Conv2d-10             [-1, 64, 1, 1]             256
# AdaptiveMaxPool2d-11             [-1, 64, 1, 1]               0
#            Conv2d-12              [-1, 4, 1, 1]             256
#              ReLU-13              [-1, 4, 1, 1]               0
#            Conv2d-14             [-1, 64, 1, 1]             256
#           Sigmoid-15             [-1, 64, 1, 1]               0
#  ChannelAttention-16             [-1, 64, 1, 1]               0
#            Conv2d-17            [-1, 1, 84, 84]              18
#           Sigmoid-18            [-1, 1, 84, 84]               0
#  SpatialAttention-19            [-1, 1, 84, 84]               0
#              VDAB-20           [-1, 64, 84, 84]               0
#        BasicBlock-21           [-1, 64, 84, 84]               0
#            Conv2d-22           [-1, 64, 84, 84]          36,864
#       BatchNorm2d-23           [-1, 64, 84, 84]             128
#            Conv2d-24           [-1, 64, 84, 84]          36,864
#       BatchNorm2d-25           [-1, 64, 84, 84]             128
# AdaptiveAvgPool2d-26             [-1, 64, 1, 1]               0
#            Conv2d-27              [-1, 4, 1, 1]             256
#              ReLU-28              [-1, 4, 1, 1]               0
#            Conv2d-29             [-1, 64, 1, 1]             256
# AdaptiveMaxPool2d-30             [-1, 64, 1, 1]               0
#            Conv2d-31              [-1, 4, 1, 1]             256
#              ReLU-32              [-1, 4, 1, 1]               0
#            Conv2d-33             [-1, 64, 1, 1]             256
#           Sigmoid-34             [-1, 64, 1, 1]               0
#  ChannelAttention-35             [-1, 64, 1, 1]               0
#            Conv2d-36            [-1, 1, 84, 84]              18
#           Sigmoid-37            [-1, 1, 84, 84]               0
#  SpatialAttention-38            [-1, 1, 84, 84]               0
#              VDAB-39           [-1, 64, 84, 84]               0
#        BasicBlock-40           [-1, 64, 84, 84]               0
#            Conv2d-41          [-1, 128, 42, 42]          73,728
#       BatchNorm2d-42          [-1, 128, 42, 42]             256
#            Conv2d-43          [-1, 128, 42, 42]         147,456
#       BatchNorm2d-44          [-1, 128, 42, 42]             256
# AdaptiveAvgPool2d-45            [-1, 128, 1, 1]               0
#            Conv2d-46              [-1, 8, 1, 1]           1,024
#              ReLU-47              [-1, 8, 1, 1]               0
#            Conv2d-48            [-1, 128, 1, 1]           1,024
# AdaptiveMaxPool2d-49            [-1, 128, 1, 1]               0
#            Conv2d-50              [-1, 8, 1, 1]           1,024
#              ReLU-51              [-1, 8, 1, 1]               0
#            Conv2d-52            [-1, 128, 1, 1]           1,024
#           Sigmoid-53            [-1, 128, 1, 1]               0
#  ChannelAttention-54            [-1, 128, 1, 1]               0
#            Conv2d-55            [-1, 1, 42, 42]              18
#           Sigmoid-56            [-1, 1, 42, 42]               0
#  SpatialAttention-57            [-1, 1, 42, 42]               0
#              VDAB-58          [-1, 128, 42, 42]               0
#            Conv2d-59          [-1, 128, 42, 42]           8,192
#       BatchNorm2d-60          [-1, 128, 42, 42]             256
#        BasicBlock-61          [-1, 128, 42, 42]               0
#            Conv2d-62          [-1, 128, 42, 42]         147,456
#       BatchNorm2d-63          [-1, 128, 42, 42]             256
#            Conv2d-64          [-1, 128, 42, 42]         147,456
#       BatchNorm2d-65          [-1, 128, 42, 42]             256
# AdaptiveAvgPool2d-66            [-1, 128, 1, 1]               0
#            Conv2d-67              [-1, 8, 1, 1]           1,024
#              ReLU-68              [-1, 8, 1, 1]               0
#            Conv2d-69            [-1, 128, 1, 1]           1,024
# AdaptiveMaxPool2d-70            [-1, 128, 1, 1]               0
#            Conv2d-71              [-1, 8, 1, 1]           1,024
#              ReLU-72              [-1, 8, 1, 1]               0
#            Conv2d-73            [-1, 128, 1, 1]           1,024
#           Sigmoid-74            [-1, 128, 1, 1]               0
#  ChannelAttention-75            [-1, 128, 1, 1]               0
#            Conv2d-76            [-1, 1, 42, 42]              18
#           Sigmoid-77            [-1, 1, 42, 42]               0
#  SpatialAttention-78            [-1, 1, 42, 42]               0
#              VDAB-79          [-1, 128, 42, 42]               0
#        BasicBlock-80          [-1, 128, 42, 42]               0
#            Conv2d-81          [-1, 256, 21, 21]         294,912
#       BatchNorm2d-82          [-1, 256, 21, 21]             512
#            Conv2d-83          [-1, 256, 21, 21]         589,824
#       BatchNorm2d-84          [-1, 256, 21, 21]             512
# AdaptiveAvgPool2d-85            [-1, 256, 1, 1]               0
#            Conv2d-86             [-1, 16, 1, 1]           4,096
#              ReLU-87             [-1, 16, 1, 1]               0
#            Conv2d-88            [-1, 256, 1, 1]           4,096
# AdaptiveMaxPool2d-89            [-1, 256, 1, 1]               0
#            Conv2d-90             [-1, 16, 1, 1]           4,096
#              ReLU-91             [-1, 16, 1, 1]               0
#            Conv2d-92            [-1, 256, 1, 1]           4,096
#           Sigmoid-93            [-1, 256, 1, 1]               0
#  ChannelAttention-94            [-1, 256, 1, 1]               0
#            Conv2d-95            [-1, 1, 21, 21]              18
#           Sigmoid-96            [-1, 1, 21, 21]               0
#  SpatialAttention-97            [-1, 1, 21, 21]               0
#              VDAB-98          [-1, 256, 21, 21]               0
#            Conv2d-99          [-1, 256, 21, 21]          32,768
#      BatchNorm2d-100          [-1, 256, 21, 21]             512
#       BasicBlock-101          [-1, 256, 21, 21]               0
#           Conv2d-102          [-1, 256, 21, 21]         589,824
#      BatchNorm2d-103          [-1, 256, 21, 21]             512
#           Conv2d-104          [-1, 256, 21, 21]         589,824
#      BatchNorm2d-105          [-1, 256, 21, 21]             512
# AdaptiveAvgPool2d-106            [-1, 256, 1, 1]               0
#           Conv2d-107             [-1, 16, 1, 1]           4,096
#             ReLU-108             [-1, 16, 1, 1]               0
#           Conv2d-109            [-1, 256, 1, 1]           4,096
# AdaptiveMaxPool2d-110            [-1, 256, 1, 1]               0
#           Conv2d-111             [-1, 16, 1, 1]           4,096
#             ReLU-112             [-1, 16, 1, 1]               0
#           Conv2d-113            [-1, 256, 1, 1]           4,096
#          Sigmoid-114            [-1, 256, 1, 1]               0
# ChannelAttention-115            [-1, 256, 1, 1]               0
#           Conv2d-116            [-1, 1, 21, 21]              18
#          Sigmoid-117            [-1, 1, 21, 21]               0
# SpatialAttention-118            [-1, 1, 21, 21]               0
#             VDAB-119          [-1, 256, 21, 21]               0
#       BasicBlock-120          [-1, 256, 21, 21]               0
#           Conv2d-121          [-1, 512, 11, 11]       1,179,648
#      BatchNorm2d-122          [-1, 512, 11, 11]           1,024
#           Conv2d-123          [-1, 512, 11, 11]       2,359,296
#      BatchNorm2d-124          [-1, 512, 11, 11]           1,024
# AdaptiveAvgPool2d-125            [-1, 512, 1, 1]               0
#           Conv2d-126             [-1, 32, 1, 1]          16,384
#             ReLU-127             [-1, 32, 1, 1]               0
#           Conv2d-128            [-1, 512, 1, 1]          16,384
# AdaptiveMaxPool2d-129            [-1, 512, 1, 1]               0
#           Conv2d-130             [-1, 32, 1, 1]          16,384
#             ReLU-131             [-1, 32, 1, 1]               0
#           Conv2d-132            [-1, 512, 1, 1]          16,384
#          Sigmoid-133            [-1, 512, 1, 1]               0
# ChannelAttention-134            [-1, 512, 1, 1]               0
#           Conv2d-135            [-1, 1, 11, 11]              18
#          Sigmoid-136            [-1, 1, 11, 11]               0
# SpatialAttention-137            [-1, 1, 11, 11]               0
#             VDAB-138          [-1, 512, 11, 11]               0
#           Conv2d-139          [-1, 512, 11, 11]         131,072
#      BatchNorm2d-140          [-1, 512, 11, 11]           1,024
#       BasicBlock-141          [-1, 512, 11, 11]               0
#           Conv2d-142          [-1, 512, 11, 11]       2,359,296
#      BatchNorm2d-143          [-1, 512, 11, 11]           1,024
#           Conv2d-144          [-1, 512, 11, 11]       2,359,296
#      BatchNorm2d-145          [-1, 512, 11, 11]           1,024
# AdaptiveAvgPool2d-146            [-1, 512, 1, 1]               0
#           Conv2d-147             [-1, 32, 1, 1]          16,384
#             ReLU-148             [-1, 32, 1, 1]               0
#           Conv2d-149            [-1, 512, 1, 1]          16,384
# AdaptiveMaxPool2d-150            [-1, 512, 1, 1]               0
#           Conv2d-151             [-1, 32, 1, 1]          16,384
#             ReLU-152             [-1, 32, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]          16,384
#          Sigmoid-154            [-1, 512, 1, 1]               0
# ChannelAttention-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 1, 11, 11]              18
#          Sigmoid-157            [-1, 1, 11, 11]               0
# SpatialAttention-158            [-1, 1, 11, 11]               0
#             VDAB-159          [-1, 512, 11, 11]               0
#       BasicBlock-160          [-1, 512, 11, 11]               0
#           Linear-161                   [-1, 23]          47,127
# ================================================================
# Total params: 11,390,183
# Trainable params: 11,390,183
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.08
# Forward/backward pass size (MB): 91.55
# Params size (MB): 43.45
# Estimated Total Size (MB): 135.08
# ----------------------------------------------------------------

# %%
if __name__ == '__main__':
  # Configuration options
  #k-fold cross-validation requires at least 2
  k_folds = 5
  num_epochs = 10
  loss_function = nn.CrossEntropyLoss()
  # For fold results
  results = {}
  # Set fixed random number seed
  torch.manual_seed(42)

# %%
  # Define the K-fold Cross Validator
  kfold = KFold(n_splits=k_folds, shuffle=True)
  # Start print
  print('--------------------------------')
# Out:
# --------------------------------

# %%
  # K-fold Cross Validation model evaluation
  for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
    # Print
    print(f'Fold-{fold}')
    print('--------------------------------')
    # Sample elements randomly from a given list of ids, no replacement.
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
    # Define data loaders for training and testing data in this fold
    trainloader = torch.utils.data.DataLoader(dataset, batch_size=16, sampler=train_subsampler)
    testloader = torch.utils.data.DataLoader(dataset, batch_size=16, sampler=test_subsampler)
    # Init the neural network
    model = ResNet18VDAB()
    # Initialize optimizer
    optimizer = torch.optim.SGD(model.parameters(), lr=5e-3)
    # Run the training loop for defined number of epochs
    # Print about training
    print('Starting training')
    for epoch in range(0, num_epochs):
      # Print epoch
      print(f'Starting epoch-{epoch+1}')
      # Set current loss value
      current_loss = 0.0
    # Evaluation for this fold
    correct, total = 0, 0
    with torch.no_grad():
      # Iterate over the test data and generate predictions
      # Iterate over the DataLoader for training data
      for i, data in enumerate(trainloader, 0):
        # Get inputs
        inputs, labels = data
        #inputs, labels = inputs.cuda(), labels.cuda() # for using data in GPU
        # Zero the gradients
        optimizer.zero_grad()
        # Perform forward pass
        outputs = model(inputs)
        # Set total and correct
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
      # Print accuracy
      print('Training accuracy for fold-%d: %.4f %%' % (fold, 100.0 * correct / total))
      print('--------------------------------')
      results[fold] = 100.0 * (correct / total)
# Process is complete.
print('Training process has finished. Saving training model.')
# Out:
# Fold-0
# --------------------------------
# Starting training
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Training accuracy for fold-0: 98.3523 %
# --------------------------------
# Fold-1
# --------------------------------
# Starting training
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Training accuracy for fold-1: 98.2014 %
# --------------------------------
# Fold-2
# --------------------------------
# Starting training
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Training accuracy for fold-2: 97.9194 %
# --------------------------------
# Fold-3
# --------------------------------
# Starting training
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Training accuracy for fold-3: 96.2903 %
# --------------------------------
# Fold-4
# --------------------------------
# Starting training
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Training accuracy for fold-4: 98.2447 %
# --------------------------------
# Training process has finished. Saving training model.

# %%
  # Print fold results
  print(f'K-fold cross validation results for {k_folds}-Folds')
  print('--------------------------------')
  sum = 0.0
  for key, value in results.items():
    print(f'Training accuracy of Fold-{key}: %.4f %%' % value)
    sum += value
    Average=sum/len(results.items())
  print(f'Average training accuracy: %.4f %%' % Average)
# Out:
# K-fold cross validation results for 5-Folds
# --------------------------------
# Training accuracy of Fold-0: 98.3523 %
# Training accuracy of Fold-1: 98.2014 %
# Training accuracy of Fold-2: 97.9194 %
# Training accuracy of Fold-3: 96.2903 %
# Training accuracy of Fold-4: 98.2447 %
# Average training accuracy: 97.8016 %

# %%
  # K-fold Cross Validation model evaluation
  for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
    # Print
    print(f'Fold-{fold}')
    print('--------------------------------')
    # Saving the model
    save_path = f'./model-fold-{fold}.pth'
    torch.save(model.state_dict(), save_path)
    # Iterate over the test data and generate predictions
    # Run the test loop for defined number of epochs
    # Print about test
    print('Starting test')
    for epoch in range(0, num_epochs):
      # Print epoch
      print(f'Starting epoch-{epoch+1}')
      # Set current loss value
      current_loss = 0.0
    # Evaluation for this fold
    correct, total = 0, 0
    with torch.no_grad():
      # Iterate over the test data and generate predictions
      # Iterate over the DataLoader for test data
      for i, data in enumerate(testloader, 0):
        # Get inputs
        inputs, labels = data
        #inputs, labels = inputs.cuda(), labels.cuda() # for using data in GPU
        # Generate outputs
        outputs = model(inputs)
        # Set total and correct
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
      # Print accuracy
      print('Test accuracy for fold-%d: %.4f %%' % (fold, 100.0 * correct / total))
      print('--------------------------------')
      results[fold] = 100.0 * (correct / total)
# Process is complete.
print('Test process has finished. Saving test model.')
# Out:
# Fold-0
# --------------------------------
# Starting test
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Test accuracy for fold-0: 96.1436 %
# --------------------------------
# Fold-1
# --------------------------------
# Starting test
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Test accuracy for fold-1: 96.1899 %
# --------------------------------
# Fold-2
# --------------------------------
# Starting test
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Test accuracy for fold-2: 96.3827 %
# --------------------------------
# Fold-3
# --------------------------------
# Starting test
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Test accuracy for fold-3: 95.9905 %
# --------------------------------
# Fold-4
# --------------------------------
# Starting test
# Starting epoch-1
# Starting epoch-2
# Starting epoch-3
# Starting epoch-4
# Starting epoch-5
# Starting epoch-6
# Starting epoch-7
# Starting epoch-8
# Starting epoch-9
# Starting epoch-10
# Test accuracy for fold-4: 96.0217 %
# --------------------------------
# Test process has finished. Saving test model.

# %%
  # Print fold results
  print(f'K-fold cross validation results for {k_folds}-Folds')
  print('--------------------------------')
  sum = 0.0
  for key, value in results.items():
    print(f'Test ccuracy of Fold-{key}: %.4f %%' % value)
    sum += value
    Average=sum/len(results.items())
  print(f'Average test accuracy: %.4f %%' % Average)
# Out:
# K-fold cross validation results for 5-Folds
# --------------------------------
# Test ccuracy of Fold-0: 96.1436 %
# Test ccuracy of Fold-1: 96.1899 %
# Test ccuracy of Fold-2: 96.3827 %
# Test ccuracy of Fold-3: 95.9905 %
# Test ccuracy of Fold-4: 96.0217 %
# Average test accuracy: 96.1456 %
